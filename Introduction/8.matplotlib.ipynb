# %% [markdown]
# <h1>Visualize your data</h1>
#
#
# <h1><b>Let's start with matplotlib</b></h1>
#
# https://matplotlib.org/
#
# matplotlib is a library specifically built to visualize your data and your results
#
# How to prepare an image
# 1. Prepare your data
# 2. Create the plot
# 3. Plot
# 4. Customize the plot
# 5. Save and show the plot

# %%
# import libraries

# %%
# Load the pre-processed data

# %% [markdown]
# <h2>Visualize the evolution in time of one single neuron</h2>

# %%
# Initialize the figure

# Save the figure

# Show the figure

# %% [markdown]
# <h2>Visualize all neurons in different subplots</h2>

# %%
# Multiple subplots

# %% [markdown]
# Find a way to have the same values on the y-axis to be able to compare the activity in a more precise way

# %% [markdown]
# <h2>Visualize the membrane potential distribution for each neuron</h2>

# %%
# Visualize the distribution of the activity of the 3 neurons at each time point

# %% [markdown]
# Visualize the overall distribution of membrane potentials

# %% [markdown]
# <h2>Visualize with an heatmap the neuronal activity in time</h2>

# %%
# Heatmap of the activity of the 3 neurons at each time point

# %% [markdown]
# <h2>Find the correlation between neural activity and visualize the correlation</h2>
