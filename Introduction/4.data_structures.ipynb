# %% [markdown]
# So far we worked with variables containing a single value (int, str, ...).
# But imagine you record the activity of a cell 10 times or 100 times, do we need to create 100 variables?

# %% [markdown]
# # 4. Data Structures
#
# A data structure is a specific way of organizing, storing, and managing data in a computer so that it can be accessed and used efficiently. Think of them as containers.
#
# Python has three basic data structures:
#
# * **Lists (list):** Ordered sequences of data that you can change.
#   Example: `[-70, -68.2, -50.5]` (A sequence of voltages)
# * **Tuples (tuple):** Ordered sequences that you CAN NOT change once created.
#   Example: `(1024, 768)` (Screen resolution for a visual stimulus)
# * **Dictionaries (dict):** Data stored as Key-Value pairs.
#   Example: `{'neuron_id': 'N1', 'is_control': True, 'voltages': [-70, -68.2, -50.5]}`

# %% [markdown]
# ### 4.1 Lists
# A list is an ordered collection of items.
#
# We use lists for sequential data that grows or updates over time, like a time-series of recorded voltages.
#
# **Notation:** Lists use square brackets `[]`.
#
# Example: `[value1, value2]`

# %%
# assign list of numbers to variable neuron_activity
[-70, -68.2, - 50.5, -39.8, -40, -61.2, -70.2]

# %% [markdown]
# Do you remember how we used indexing [0] and slicing [0:3] on strings?
# It works the exact same way here!

# %%
# Get the very first recording (Index 0)

# %%
# Slice the first three recordings (Indices 0, 1, and 2)

# Slice the last three recordings (Indices -3, -2, and -1)

# %%
# Exercise: I want to read the last recording, but I get an error. Why? Can you fix it?
print(neuron_activity[8])

# %% [markdown]
# **Useful List Methods**
#
# * We can add a new item to the end of our list using `.append()`.
# * We can remove an item from the list using `.pop()`.
# * We can sort the items of the list using `.sort()`
#
# 🔎 [What else can we do?](https://docs.python.org/3/tutorial/datastructures.html)

# %%
# Add a new measurement of -71.5 to the end of the neuron_activity list
neuron_activity
print(f"Updated list: {neuron_activity}")

# %% [markdown]
# ### 4.2 Tuples
# Tuples are very similar to lists, but with one massive difference: **they cannot be changed once created.**
# This is called being "immutable".
#
# We use tuples for data that must remain constant so we don't accidentally overwrite it.
#
# **Notation:** Tuples use parentheses `()`.
#
# Example: `(value1, value2)`

# %%
# Let's define the screen resolution (width, height)

# %%
# We can read data from a tuple using the exact same indexing we used for lists!

# %%
# what happens if we try to change the width of our screen? Let's try to modify the first element of the tuple:
screen_resolution

# %% [markdown]
# ### 4.3 Dictionaries
# Instead of using a numbered index (like 0, 1, 2) to find information, dictionaries use text labels, which we call "keys".
#
# **Notation:** Dictionaries use curly brackets `{}` and a `key: value` format separated by commas.
#
# Example: `{key1: value1, key2: value2}`

# %%
# Let's create a dictionary with information about one recording.
# information: neuron_id = N1, brain_region = Hippocampus, is_control= True, voltages= neuron_activity 
# Notice that we can even put our entire 'neuron_activity' list inside it!
# 
recording_info = # complete the dictionary with the information above
print(recording_info)

# %%
# How do we read the neuron_id from this dictionary?
# Instead of asking for index [0], we ask for the label (key) we want:

# %%
# How do we check if this recording is a control cell or not?

# %%
# We can even access our entire list of voltages through the dictionary!

# %% [markdown]
# **Adding or updating information**
#
# Just like we can append to a list, we can add new keys to a dictionary.

# %%
# Let's say we just recorded the cell, but we don't know what type it is yet.
# Add a new key to the dictionary called "cell_type" and set it to "Unknown":


print("Updated recording info:")
print(recording_info)

# %%
# Exercise: After checking the cell's properties, you realize it is an interneuron!
# Update the "cell_type" to "Interneuron".

# %%
# Exercise: Read the error message. What is the problem? Can you fix it?
print(recording_info['brain_regiion'])

# %% [markdown]
# **Useful Dictionary Methods**
#
# What do these methods return?
# * `.keys()`
# * `.values()`
# * `.items()`

# %%
# How can we access the first recoded value in the 'voltages' list through the dictionary?
